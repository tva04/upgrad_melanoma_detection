# %% [markdown]
# <a href="https://colab.research.google.com/github/tva04/upgrad_melanoma_detection/blob/main/anand_melanoma_detection_assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Melanoma Detection Assessment

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ## 1: Prerequisite

# %% [markdown]
# *   Importing Libraries
# *   Load the Row images
# *   Use Keras for preprocessing

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from glob import glob
import seaborn as sns

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.preprocessing.image import load_img

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (11.1.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (4.67.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from Augmentor) (1.26.4)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %%
import Augmentor

# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Read from GDrive

# %%
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test =  pathlib.Path("/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %% [markdown]
# Checking the image count

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# Use Keras for pre-processing

# %%
# Setting parameters
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Train-Test data split (80-20)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %% [markdown]
# Define Validation Data set

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %% [markdown]
# Define Classess

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
len(class_names)
# Out:
# 9

# %% [markdown]
# # 2: Data Visualisation

# %% [markdown]
# Visualising all the 9 classess

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.
#
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 3: Create the Model

# %% [markdown]
#  CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
target_labels = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## 3.1 Compile the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 9)                   │           1,161 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3.2 Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.2210 - loss: 2.0814 - val_accuracy: 0.2953 - val_loss: 1.9382
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.3866 - loss: 1.7476 - val_accuracy: 0.4609 - val_loss: 1.5593
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.4684 - loss: 1.5147 - val_accuracy: 0.4855 - val_loss: 1.4913
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.5369 - loss: 1.3430 - val_accuracy: 0.5168 - val_loss: 1.3935
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.5366 - loss: 1.2898 - val_accuracy: 0.5459 - val_loss: 1.3314
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.5978 - loss: 1.1056 - val_accuracy: 0.5280 - val_loss: 1.3823
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.6096 - loss: 1.0634 - val_accuracy: 0.5615 - val_loss: 1.2964
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.6471 - loss: 0.9969 - val_accuracy: 0.5436 - val_loss: 1.4454
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - accuracy: 0.6549 - loss: 0.9326 - val_accuracy: 0.5347 - val_loss: 1.4342
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.7142 - loss: 0.8113 - val_accuracy: 0.5347 - val_loss: 1.5246
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7297 - loss: 0.7558 - val_accuracy: 0.5168 - val_loss: 1.6255
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.7310 - loss: 0.7119 - val_accuracy: 0.5324 - val_loss: 1.6432
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.7642 - loss: 0.6313 - val_accuracy: 0.5123 - val_loss: 1.7364
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.7951 - loss: 0.5840 - val_accuracy: 0.5459 - val_loss: 1.7459
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.8381 - loss: 0.4661 - val_accuracy: 0.5280 - val_loss: 1.8514
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.8364 - loss: 0.4544 - val_accuracy: 0.5526 - val_loss: 1.9683
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8537 - loss: 0.4095 - val_accuracy: 0.5190 - val_loss: 2.1941
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8436 - loss: 0.4172 - val_accuracy: 0.5369 - val_loss: 2.3510
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.8591 - loss: 0.3788 - val_accuracy: 0.5145 - val_loss: 2.1735
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.8716 - loss: 0.3375 - val_accuracy: 0.5168 - val_loss: 2.2039

# %% [markdown]
# ## 3.3 Visualising training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 3.4. Summary

# %% [markdown]
# - The model's training accuracy shows a steady increase of up to 90%, while the validation accuracy remains consistently around 55%.
#
# - A high training accuracy suggests that the model has effectively captured the noise within the data. However, its poor performance on the validation data indicates a lack of generalizability.
#
# - These observations confirm the presence of overfitting. To address this issue, augmentation techniques will be employed. Given the limited training data available, new samples will be generated by making slight modifications to existing data (such as horizontal/vertical image flipping, minor image rotations, etc.), which will then be used to train the model.

# %% [markdown]
# ## 3.5 Augmentor

# %%
augmentation_data = Sequential([
    layers.RandomFlip("horizontal_and_vertical",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.1)
])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented_images = augmentation_data(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.title(class_names[labels[0]])
        plt.axis("off")

# %% [markdown]
# # 4. Create Model (After Augmentor)

# %%
model = Sequential([
  augmentation_data,
  layers.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])

# %% [markdown]
# ## 4.1 Compiling

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ## 4.2 Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.2146 - loss: 2.5087 - val_accuracy: 0.2349 - val_loss: 2.0952
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.2985 - loss: 1.9093 - val_accuracy: 0.4049 - val_loss: 1.6458
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.4185 - loss: 1.6347 - val_accuracy: 0.4966 - val_loss: 1.5318
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.4924 - loss: 1.4984 - val_accuracy: 0.4966 - val_loss: 1.4138
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.4774 - loss: 1.4173 - val_accuracy: 0.4989 - val_loss: 1.4635
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.4754 - loss: 1.4746 - val_accuracy: 0.5101 - val_loss: 1.3830
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5183 - loss: 1.3593 - val_accuracy: 0.4944 - val_loss: 1.4272
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5265 - loss: 1.3703 - val_accuracy: 0.5235 - val_loss: 1.3445
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5300 - loss: 1.3048 - val_accuracy: 0.5213 - val_loss: 1.3815
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5528 - loss: 1.2757 - val_accuracy: 0.5190 - val_loss: 1.3011
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5470 - loss: 1.2502 - val_accuracy: 0.5503 - val_loss: 1.3315
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5688 - loss: 1.1990 - val_accuracy: 0.5302 - val_loss: 1.3163
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5705 - loss: 1.2011 - val_accuracy: 0.5056 - val_loss: 1.4913
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5406 - loss: 1.2334 - val_accuracy: 0.5570 - val_loss: 1.3383
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.5815 - loss: 1.1658 - val_accuracy: 0.5235 - val_loss: 1.3445
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.5643 - loss: 1.2072 - val_accuracy: 0.5414 - val_loss: 1.3482
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5534 - loss: 1.1804 - val_accuracy: 0.5436 - val_loss: 1.3337
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.5816 - loss: 1.1636 - val_accuracy: 0.5190 - val_loss: 1.2681
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.6140 - loss: 1.0964 - val_accuracy: 0.5280 - val_loss: 1.3109
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.5899 - loss: 1.1574 - val_accuracy: 0.5436 - val_loss: 1.2892

# %% [markdown]
# ## 4.3 Validation

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## 4.4 Observartions

# %% [markdown]
# - By leveraging augmented data, overfitting has been effectively addressed.
#
# - The training and validation accuracies of the aforementioned model now fall within a similar range.
#
# - Both the training and validation performances are poor, indicating that the model is now exhibiting underfitting.

# %% [markdown]
# # 5: Find the class distribution & Generate Image (Augmentor)

# %%
## find the image path for all class labels (lesions)
images_path_list = [ i for i in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]

## Extract the class labels (lesions)
lesions_list = [ os.path.basename(os.path.dirname(j)) for j in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesions_list))
# Out:
# 2239

# %%
# Extract image path and class label in a dictionary
image_dict = dict(zip(images_path_list, lesions_list))
print(list(image_dict.items())[:5])
# Out:
# [('/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/ISIC_0000143.jpg', 'melanoma'), ('/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/ISIC_0000139.jpg', 'melanoma'), ('/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/ISIC_0000279.jpg', 'melanoma'), ('/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/ISIC_0000172.jpg', 'melanoma'), ('/content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/ISIC_0000170.jpg', 'melanoma')]

# %%
lesions_df = pd.DataFrame(list(image_dict.items()), columns=['Image Path', 'Label'])
lesions_df.head()
# Out:
#                                           Image Path     Label
# 0  /content/gdrive/My Drive/Upgrad-EPGP-AIML/work...  melanoma
# 1  /content/gdrive/My Drive/Upgrad-EPGP-AIML/work...  melanoma
# 2  /content/gdrive/My Drive/Upgrad-EPGP-AIML/work...  melanoma
# 3  /content/gdrive/My Drive/Upgrad-EPGP-AIML/work...  melanoma
# 4  /content/gdrive/My Drive/Upgrad-EPGP-AIML/work...  melanoma

# %%
lesions_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
# Visualize the distribution of classes using a countplot

plt.figure(figsize=(10, 8))
sns.countplot(y="Label", data=lesions_df)
plt.title('No. of images belonging to a Type v/s Types of Skin Lesion', fontsize=16)
plt.xlabel('No. of images in a particular skin lesion type', fontsize=14)
plt.ylabel('Skin Lesion Types', fontsize=14)
plt.show()

# %% [markdown]
# ## 5.1 Observations

# %% [markdown]
# - A clear class imbalance is evident in the training data.
#
# - The class *seborrheic keratosis* represents the smallest proportion of samples, accounting for approximately 3.44%.
#
# - *Pigmented benign keratosis* and "melanoma" significantly outnumber the other classes, representing approximately 20.63% and 19.56% of the data, respectively.

# %% [markdown]
# ## 5.2 Train the model on the data created using Augmentor

# %%
path_to_training_dataset = str(data_dir_train) + '/'

for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    ## We are adding 500 samples per class to make sure that none of the classes are sparse.
    p.sample(500)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AADD1707010>: 100%|██████████| 500/500 [00:26<00:00, 18.68 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7AADD15D9310>: 100%|██████████| 500/500 [00:24<00:00, 20.42 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AADD2756D50>: 100%|██████████| 500/500 [00:24<00:00, 20.60 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7AADD1424250>: 100%|██████████| 500/500 [01:45<00:00,  4.74 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=2725x2082 at 0x7AADD15DA050>: 100%|██████████| 500/500 [01:41<00:00,  4.91 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AADD20188D0>: 100%|██████████| 500/500 [00:23<00:00, 21.07 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7AADD2031A90>: 100%|██████████| 500/500 [00:48<00:00, 10.27 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AADD21D2D90>: 100%|██████████| 500/500 [00:24<00:00, 20.21 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Upgrad-EPGP-AIML/workspace/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7AADD2049450>: 100%|██████████| 500/500 [00:25<00:00, 19.56 Samples/s]

# %%
# Verifying the total count of images after the augmentation
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ## 5.3: Validating the train data set

# %%
# extracting the augmented image paths in a list
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()), columns=['Image Path', 'Label'])
new_df = pd.concat([lesions_df, df2], ignore_index=True)
new_df.shape
# Out:
# (6739, 2)

# %%
# Inspecting the classes after adding 500 samples per label
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %% [markdown]
# # 6. Create New Model (Using new Augmentor)

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Training data set

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e462144e35e1> in <cell line: 0>()
# ----> 1 train_ds = tf.keras.preprocessing.image_dataset_from_directory(
#       2   data_dir_train,
#       3   seed=123,
#       4   validation_split = 0.2,
#       5   subset = 'training',
#
# NameError: name 'tf' is not defined

# %% [markdown]
# Validation data set

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# Create Model

# %%
model = Sequential([
  augmentation_data,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(32, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Conv2D(64, (3, 3), padding='same', activation=tf.nn.relu),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation=tf.nn.relu),
  layers.Dense(target_labels)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1769f640f6d2> in <cell line: 0>()
# ----> 1 model = Sequential([
#       2   augmentation_data,
#       3   layers.experimental.preprocessing.Rescaling(1./255),
#       4   layers.Conv2D(16, (3, 3), padding='same', activation=tf.nn.relu),
#       5   layers.MaxPooling2D(),
#
# NameError: name 'Sequential' is not defined

# %%
model.summary()

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# ModelCheckpoint callback is employed alongside the model.fit() training process to periodically save the model
# or its weights (in a checkpoint file)
checkpoint = ModelCheckpoint("model.keras", monitor="val_accuracy", save_best_only=True, mode="auto", verbose=1)

# Early stop the training when a monitored metric ceases to show improvement
earlystop = EarlyStopping(monitor="val_accuracy", patience=5, mode="auto", verbose=1)

# %% [markdown]
# Train Model

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks=[checkpoint, earlystop]
)
# Out:
# Epoch 1/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2704 - loss: 3.4510
# Epoch 1: val_accuracy improved from -inf to 0.08315, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 412s 2s/step - accuracy: 0.2706 - loss: 3.4439 - val_accuracy: 0.0831 - val_loss: 25.4861
# Epoch 2/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3965 - loss: 1.5538
# Epoch 2: val_accuracy improved from 0.08315 to 0.11507, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 431s 2s/step - accuracy: 0.3964 - loss: 1.5538 - val_accuracy: 0.1151 - val_loss: 15.8082
# Epoch 3/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4110 - loss: 1.5021
# Epoch 3: val_accuracy improved from 0.11507 to 0.33927, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 441s 2s/step - accuracy: 0.4110 - loss: 1.5021 - val_accuracy: 0.3393 - val_loss: 2.4925
# Epoch 4/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4452 - loss: 1.4516
# Epoch 4: val_accuracy did not improve from 0.33927
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.4451 - loss: 1.4515 - val_accuracy: 0.2970 - val_loss: 2.3356
# Epoch 5/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4428 - loss: 1.4084
# Epoch 5: val_accuracy improved from 0.33927 to 0.44989, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 429s 2s/step - accuracy: 0.4428 - loss: 1.4083 - val_accuracy: 0.4499 - val_loss: 1.4064
# Epoch 6/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4674 - loss: 1.3579
# Epoch 6: val_accuracy improved from 0.44989 to 0.45731, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.4674 - loss: 1.3579 - val_accuracy: 0.4573 - val_loss: 1.4329
# Epoch 7/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4667 - loss: 1.3414
# Epoch 7: val_accuracy did not improve from 0.45731
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 397s 2s/step - accuracy: 0.4667 - loss: 1.3413 - val_accuracy: 0.4462 - val_loss: 1.3070
# Epoch 8/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4819 - loss: 1.2865
# Epoch 8: val_accuracy did not improve from 0.45731
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 432s 2s/step - accuracy: 0.4819 - loss: 1.2864 - val_accuracy: 0.3912 - val_loss: 1.7782
# Epoch 9/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5082 - loss: 1.2689
# Epoch 9: val_accuracy improved from 0.45731 to 0.48255, saving model to model.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.5082 - loss: 1.2689 - val_accuracy: 0.4826 - val_loss: 1.2527
# Epoch 10/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5019 - loss: 1.2587
# Epoch 10: val_accuracy did not improve from 0.48255
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 447s 2s/step - accuracy: 0.5019 - loss: 1.2587 - val_accuracy: 0.4751 - val_loss: 1.3451
# Epoch 11/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5295 - loss: 1.2294
# Epoch 11: val_accuracy did not improve from 0.48255
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 393s 2s/step - accuracy: 0.5295 - loss: 1.2294 - val_accuracy: 0.4736 - val_loss: 1.3205
# Epoch 12/50
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5293 - loss: 1.1985
# Epoch 12: val_accuracy did not improve from 0.48255
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 443s 2s/step - accuracy: 0.5292 - loss: 1.1986 - val_accuracy: 0.4395 - val_loss: 1.4212
# Epoch 13/50
# 132/169 ━━━━━━━━━━━━━━━━━━━━ 1:17 2s/step - accuracy: 0.5328 - loss: 1.2197

# %% [markdown]
# Validation

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab192aeb141e> in <cell line: 0>()
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3
#       4 loss = history.history['loss']
#       5 val_loss = history.history['val_loss']
#
# NameError: name 'history' is not defined

# %% [markdown]
# Observations

# %% [markdown]
# The ultimate model showcases well-balanced performance, displaying no signs of underfitting or overfitting.
#
# The implementation of class rebalancing has notably enhanced the model's performance across both training and validation datasets.
#
# Following 37 epochs, the final model attains an accuracy of 84% on the training set and approximately 79% on the validation set.
#
# The narrow divergence between training and validation accuracies underscores the robust generalization capability of the final CNN model.
#
# The addition of batch normalization failed to enhance both training and validation accuracy.

# %% [markdown]
# # 7: Model Evaluation

# %%
# Evaluating our model on one of the instances in the test set

image_path_test = os.path.join(data_dir_test, class_names[1], '*')
test_image = glob(image_path_test)
test_image = load_img(test_image[-1], target_size=(180, 180, 3))
plt.imshow(test_image)
plt.grid(False)

img = np.expand_dims(test_image, axis=0)
predicted = model.predict(img)
predicted = np.argmax(predicted)
predicted_class = class_names[predicted]
print("Actual Class: " + class_names[1] +'\n'+ "Predicted Class: " + predicted_class)
